# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/skygeni_sales_data.csv')
df.sample(5)
# Out:
#      deal_id created_date closed_date sales_rep_id    industry         region  \
# 2316  D02317   2023-04-24  2023-08-05       rep_15        SaaS  North America
# 925   D00926   2023-04-21  2023-06-11       rep_12     FinTech           APAC
# 2069  D02070   2023-10-14  2023-11-18        rep_8      EdTech           APAC
# 3636  D03637   2023-02-22  2023-04-26       rep_23   Ecommerce         Europe
# 3648  D03649   2023-12-02  2023-12-31       rep_13  HealthTech           APAC
#
#      product_type lead_source deal_stage  deal_amount  sales_cycle_days  \
# 2316   Enterprise    Outbound       Demo        23268               103
# 925           Pro     Inbound   Proposal         3565                51
# 2069          Pro     Partner       Demo        12379                35
# 3636   Enterprise     Inbound       Demo         8151                63
# 3648          Pro     Inbound       Demo        72054                29
#
#      outcome
# 2316     Won
# 925      Won
# 2069     Won
# 3636     Won
# 3648    Lost

# %%
df.sort_values(by='created_date', ascending=True)
# Out:
#      deal_id created_date closed_date sales_rep_id    industry         region  \
# 3321  D03322   2023-01-01  2023-03-26        rep_3  HealthTech  North America
# 3462  D03463   2023-01-01  2023-02-09       rep_18   Ecommerce         Europe
# 1639  D01640   2023-01-01  2023-02-20       rep_17     FinTech          India
# 868   D00869   2023-01-01  2023-01-14       rep_20     FinTech          India
# 4486  D04487   2023-01-01  2023-02-22        rep_4      EdTech           APAC
# ...      ...          ...         ...          ...         ...            ...
# 4198  D04199   2024-03-26  2024-04-04       rep_22  HealthTech  North America
# 3519  D03520   2024-03-26  2024-04-03       rep_16  HealthTech  North America
# 3937  D03938   2024-03-26  2024-04-15       rep_10        SaaS  North America
# 3615  D03616   2024-03-26  2024-05-02       rep_20   Ecommerce           APAC
# 317   D00318   2024-03-26  2024-05-14       rep_11      EdTech           APAC
#
#      product_type lead_source   deal_stage  deal_amount  sales_cycle_days  \
# 3321   Enterprise     Partner  Negotiation        23606                84
# 3462   Enterprise    Outbound       Closed        41634                39
# 1639          Pro     Inbound       Closed         8717                50
# 868          Core     Partner     Proposal        11473                13
# 4486   Enterprise     Partner    Qualified        33416                52
# ...           ...         ...          ...          ...               ...
# 4198         Core     Partner    Qualified         7634                 9
# 3519         Core    Outbound         Demo        48454                 8
# 3937          Pro     Inbound    Qualified         3305                20
# 3615          Pro     Partner       Closed         9523                37
# 317           Pro    Referral    Qualified        15785                49
#
#      outcome  created_month  created_quarter  created_weekday  closed_month  \
# 3321     Won              1                1                6             3
# 3462    Lost              1                1                6             2
# 1639     Won              1                1                6             2
# 868     Lost              1                1                6             1
# 4486    Lost              1                1                6             2
# ...      ...            ...              ...              ...           ...
# 4198    Lost              3                1                1             4
# 3519    Lost              3                1                1             4
# 3937    Lost              3                1                1             4
# 3615     Won              3                1                1             5
# 317     Lost              3                1                1             5
#
#       closed_quarter  closed_weekday sales_cycle_bucket  is_won acv_bucket
# 3321               1               6               2-3m       1       High
# 3462               1               3               1-2m       0  Very High
# 1639               1               0               1-2m       1        Mid
# 868                1               5                <2w       0        Mid
# 4486               1               2               1-2m       0       High
# ...              ...             ...                ...     ...        ...
# 4198               2               3                <2w       0        Mid
# 3519               2               2                <2w       0  Very High
# 3937               2               0               2-4w       0        Low
# 3615               2               3               1-2m       1        Mid
# 317                2               1               1-2m       0       High
#
# [5000 rows x 21 columns]

# %%
min(df['created_date']), max(df['created_date'])
# Out:
# (Timestamp('2023-01-01 00:00:00'), Timestamp('2024-03-26 00:00:00'))

# %%
# Data goes from 1st Jan 2023 to 26 March 2024

# %% [markdown]
# # 1. Problem Framing
# 1. What do you think is the real business problem here?
# 2. What key questions should an AI system answer for the CRO?
# 3. What metrics matter most for diagnosing win rate issues?
# 4. What assumptions are you making about the data or business?

# %% [markdown]
# 1. Despite a healthy pipeline volume, conversion efficiency has degraded, suggesting misalignment in deal quality, sales execution, or pipeline composition.
# 2. Ai must answer segments that are responsible for dragging the win rate down, find pain points for failure to make the deal (who we sell to, how we sell to or where deals stall)
#     - Who we sell to can be explained via EDA, the kind of dealers that we can't close a deal with
#     - How we sell to could be better explained via continuous reports/emails/remarks/employee etc
#     - Where deals stall can be found via EDA and explainable ML models, they can find patterns from factors and situations where the choking points are
# 3. Metrics that matter most for diagnosing the win rate issues are
#     - win rate
#     - avg deal cycle time
#     - ACV by segment
#     - Adding further diagnostic metrics such as stage leakage rate (ration of deals lost after reaching proposal/negotiation), pipeline quality ratio (finalized ACV/ Total Qualified ACV)
#     - late-stage loss rate
#     - deal aging index (actual cycle/ median cycle for that segment or group); differs for each group, example: sales_rep_id, product_type, lead_source, etc
# 4. Assumptions taken for the study
#    - outcome labels are accurate
#    - stage progression is consistent
#    - sales process did not drastically change mid-period
#    - no major pricing change occured

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ### Philosophy for target
# 1. Is win rate actually dropping ... and where?
# 2. which segements are bleeding value
# 3. Bottlenecks in the funnnel that contributes to leads lost
# 4. Representatives or Deal dynamics could be the issue --> Market fails to accept deals with this pattern

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   deal_id           5000 non-null   object
#  1   created_date      5000 non-null   object
#  2   closed_date       5000 non-null   object
#  3   sales_rep_id      5000 non-null   object
#  4   industry          5000 non-null   object
#  5   region            5000 non-null   object
#  6   product_type      5000 non-null   object
#  7   lead_source       5000 non-null   object
#  8   deal_stage        5000 non-null   object
#  9   deal_amount       5000 non-null   int64
#  10  sales_cycle_days  5000 non-null   int64
#  11  outcome           5000 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 468.9+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# good, no nulls and duplicates

# %%
df.describe()
# Out:
#          deal_amount  sales_cycle_days
# count    5000.000000       5000.000000
# mean    26286.492800         63.751800
# std     27689.230136         32.731405
# min      2002.000000          7.000000
# 25%      6611.000000         35.750000
# 50%     14171.500000         64.000000
# 75%     39062.250000         92.000000
# max    100000.000000        120.000000

# %%
# Basic sanity
print(True if df["deal_id"].is_unique else False)
print(True if set(df["outcome"].unique()) == {"Won", "Lost"} else False)
print(True if list((df["closed_date"] - df["created_date"]).dt.days) == list(df['sales_cycle_days']) else False)
# Out:
# True
# True
# True

# %%
df_copy = df.copy()

# %% [markdown]
# ### Feature Engineering

# %%
df["created_date"] = pd.to_datetime(df["created_date"])
df["closed_date"] = pd.to_datetime(df["closed_date"])

df["created_month"] = df["created_date"].dt.month
df["created_quarter"] = df["created_date"].dt.quarter
df["created_year"] = df["created_date"].dt.year
df['created_year_and_quarter'] = df["created_date"].dt.to_period("Q").astype(str)
df["created_weekday"] = df["created_date"].dt.weekday

df["closed_month"] = df["closed_date"].dt.month
df["closed_quarter"] = df["closed_date"].dt.quarter
df["closed_year"] = df["closed_date"].dt.year
df['created_year_and_quarter'] = df["closed_date"].dt.to_period("Q").astype(str)
df["closed_weekday"] = df["closed_date"].dt.weekday

# Time buckets (helps CRO thinking)
df["sales_cycle_bucket"] = pd.cut(
    df["sales_cycle_days"],
    bins=[0, 14, 30, 60, 90, np.inf],
    labels=["<2w", "2-4w", "1-2m", "2-3m", "3m+"]
)

# Binary outcome
df["is_won"] = (df["outcome"] == "Won").astype(int)

# ACV buckets (very important) --> Right skewed data, hence log transformed
df["acv_bucket"] = pd.qcut(
    df["deal_amount"], 
    # np.log1p(df["deal_amount"]), 
    q=4,
    labels=["Low", "Mid", "High", "Very High"]
)

# doesn't matter if I apply log or not in pd.qcut as log is a monotonic function (preserves order) 
# and qcut works by splitting thr ranked data into equal sized groups
# hence ranking order of values doesn't change post log applying
# NOTE: for strictly qcut into bucket applications, skip applying log as it is just additional compute, 
# look at examples/qcut-example.ipynb for sanity check

# %% [markdown]
# ### ACV (Annual Contract Value) bucket distribution

# %%
df.groupby("acv_bucket")["deal_amount"].agg(["min", "max", "sum", "median", "mean", "count"])
# Out:
# C:\Users\robot\AppData\Local\Temp\ipykernel_12820\1086105544.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("acv_bucket")["deal_amount"].agg(["min", "max", "sum", "median", "mean", "count"])
#               min     max       sum   median        mean  count
# acv_bucket
# Low          2002    6608   5349883   4311.0   4279.9064   1250
# Mid          6612   14165  12369579   9765.0   9895.6632   1250
# High        14178   39053  26021768  18495.0  20817.4144   1250
# Very High   39090  100000  87691234  70287.5  70152.9872   1250

# %%
df[(df['deal_amount'] < 6612) & (df['deal_amount'] > 6608)] # sanity check
# Out:
# Empty DataFrame
# Columns: [deal_id, created_date, closed_date, sales_rep_id, industry, region, product_type, lead_source, deal_stage, deal_amount, sales_cycle_days, outcome, created_month, created_quarter, created_weekday, closed_month, closed_quarter, closed_weekday, sales_cycle_bucket, is_won, acv_bucket]
# Index: []

# %%
# Group by category and get min and max for each
ranges = df.groupby("acv_bucket")["deal_amount"].agg(["min", "max"])

# Optional: sum if you still want bar heights to show total
totals = df.groupby("acv_bucket")["deal_amount"].sum()

plt.figure(figsize=(15, 6))
ax = totals.plot(kind="bar")

# Add min–max range labels on top of each bar
for i, (mn, mx) in enumerate(zip(ranges["min"], ranges["max"])):
    ax.text(i, totals[i] + max(totals)*0.01, f"{mn:,} – {mx:,}", 
            ha='center', va='bottom', fontsize=10)

plt.xlabel("Category")
plt.ylabel("Total Amount")
plt.title("Total Amount by Category with Deal Ranges")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\robot\AppData\Local\Temp\ipykernel_12820\3581422231.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ranges = df.groupby("acv_bucket")["deal_amount"].agg(["min", "max"])
# C:\Users\robot\AppData\Local\Temp\ipykernel_12820\3581422231.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   totals = df.groupby("acv_bucket")["deal_amount"].sum()
# C:\Users\robot\AppData\Local\Temp\ipykernel_12820\3581422231.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(i, totals[i] + max(totals)*0.01, f"{mn:,} – {mx:,}",

# %%
df.sample(10)
# Out:
#      deal_id created_date closed_date sales_rep_id    industry         region  \
# 755   D00756   2023-09-30  2023-11-24        rep_2        SaaS         Europe
# 373   D00374   2023-11-02  2023-11-15       rep_18      EdTech  North America
# 1903  D01904   2023-02-11  2023-04-18       rep_11     FinTech           APAC
# 3380  D03381   2023-11-22  2023-12-30       rep_20      EdTech         Europe
# 4662  D04663   2023-02-10  2023-03-05        rep_3   Ecommerce           APAC
# 282   D00283   2024-02-04  2024-05-19       rep_11   Ecommerce  North America
# 1223  D01224   2023-07-31  2023-08-30       rep_23      EdTech           APAC
# 3252  D03253   2023-10-25  2023-12-23        rep_1        SaaS          India
# 3389  D03390   2023-08-17  2023-12-15       rep_16  HealthTech           APAC
# 3717  D03718   2023-12-09  2023-12-19       rep_25  HealthTech         Europe
#
#      product_type lead_source   deal_stage  deal_amount  sales_cycle_days  \
# 755    Enterprise     Partner         Demo        76300                55
# 373    Enterprise     Partner       Closed        18086                13
# 1903         Core    Referral     Proposal        17512                66
# 3380          Pro    Referral       Closed        81938                38
# 4662   Enterprise    Referral       Closed         6680                23
# 282    Enterprise     Partner  Negotiation         9731               105
# 1223          Pro     Partner     Proposal        14547                30
# 3252          Pro     Partner    Qualified        34383                59
# 3389          Pro     Inbound    Qualified        14056               120
# 3717   Enterprise    Outbound         Demo        20752                10
#
#      outcome  created_month  created_quarter  created_weekday  closed_month  \
# 755     Lost              9                3                5            11
# 373     Lost             11                4                3            11
# 1903     Won              2                1                5             4
# 3380    Lost             11                4                2            12
# 4662    Lost              2                1                4             3
# 282     Lost              2                1                6             5
# 1223    Lost              7                3                0             8
# 3252     Won             10                4                2            12
# 3389     Won              8                3                3            12
# 3717    Lost             12                4                5            12
#
#       closed_quarter  closed_weekday sales_cycle_bucket  is_won acv_bucket
# 755                4               4               1-2m       0  Very High
# 373                4               2                <2w       0       High
# 1903               2               1               2-3m       1       High
# 3380               4               5               1-2m       0  Very High
# 4662               1               6               2-4w       0        Mid
# 282                2               6                3m+       0        Mid
# 1223               3               2               2-4w       0       High
# 3252               4               5               1-2m       1       High
# 3389               4               4                3m+       1        Mid
# 3717               4               1                <2w       0       High

# %% [markdown]
# ### Distribution of ['deal_amount', 'sales_cycle_time']

# %%
def histogram(data, bins:int = 20):
    plt.figure(figsize=(15, 6))

    counts, bin_edges, patches = plt.hist(
        data,
        bins=bins,
        edgecolor='black'
    )

    total = counts.sum()
    percentages = counts / total * 100

    # Bin centers for ticks and labels
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    plt.xticks(bin_centers, rotation=45)

    # Add percentage labels above bars
    for count, pct, patch in zip(counts, percentages, patches):
        if count > 0:
            plt.text(
                patch.get_x() + patch.get_width() / 2,
                count,
                f'{pct:.1f}%',
                ha='center',
                va='bottom',
                fontsize=9
            )

    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Distribution of Integer Values')

    plt.tight_layout()
    plt.show()

# %%
histogram(df['deal_amount'])

# %%
histogram(np.log1p(df['deal_amount']))

# %%
## above data is right skewed, most frequent deal_amount (AVC) are of lower numbers from 2000 to 22000 approximately

# %%
histogram(df['sales_cycle_days'], bins=50)

# %%
## distribution of period of sales_cycles is normal for all the values in the data

# %% [markdown]
# ### Global Health Check

# %%
df["outcome"].value_counts(normalize=True)
# Out:
# outcome
# Lost    0.5474
# Won     0.4526
# Name: proportion, dtype: float64

# %%
num_cols = ["deal_amount", "sales_cycle_days"]

df.groupby("is_won")[num_cols].describe()
# Out:
#        deal_amount                                                       \
#              count          mean           std     min     25%      50%
# is_won
# 0           2737.0  25883.516989  27488.326854  2002.0  6615.0  13804.0
# 1           2263.0  26773.874503  27928.597391  2006.0  6602.0  14623.0
#
#                           sales_cycle_days                                   \
#             75%       max            count       mean        std  min   25%
# is_won
# 0       37082.0   99996.0           2737.0  64.230179  32.545913  7.0  37.0
# 1       40565.0  100000.0           2263.0  63.173221  32.952274  7.0  34.0
#
#
#          50%   75%    max
# is_won
# 0       64.0  93.0  120.0
# 1       63.0  91.5  120.0

# %%
## pretty evenly distributed, high in volume, yet only about half of the volume efforts gain a positive outcome

# %%
win_rate_trend = (
    df.groupby(["created_year","created_quarter","created_month"])
      .agg(
          deals=("deal_id", "count"),
          win_rate=("is_won", "mean"),
          revenue_generated=("deal_amount", "sum")
      )
      .reset_index()
)

win_rate_trend["win_rate"] *= 100
win_rate_trend['successful_deals'] = win_rate_trend['win_rate'] * win_rate_trend['deals']

win_rate_trend
# Out:
#     created_year  created_quarter  created_month  deals   win_rate  \
# 0           2023                1              1    321  43.302181
# 1           2023                1              2    321  45.482866
# 2           2023                1              3    364  42.582418
# 3           2023                2              4    335  47.761194
# 4           2023                2              5    348  41.666667
# 5           2023                2              6    331  43.504532
# 6           2023                3              7    325  48.000000
# 7           2023                3              8    364  47.252747
# 8           2023                3              9    317  44.479495
# 9           2023                4             10    329  44.680851
# 10          2023                4             11    333  47.447447
# 11          2023                4             12    351  51.566952
# 12          2024                1              1    324  39.506173
# 13          2024                1              2    328  47.865854
# 14          2024                1              3    309  43.365696
#
#     revenue_generated  successful_deals
# 0             7810793           13900.0
# 1             8539285           14600.0
# 2             8935999           15500.0
# 3             9152627           16000.0
# 4             8956884           14500.0
# 5             9006044           14400.0
# 6             8775231           15600.0
# 7             9103600           17200.0
# 8             8496269           14100.0
# 9             9028665           14700.0
# 10            8955236           15800.0
# 11            8993656           18100.0
# 12            8543369           12800.0
# 13            9145098           15700.0
# 14            7989708           13400.0

# %%
win_rate_trend = (
    df.groupby(["created_year_and_quarter"])
      .agg(
          deals=("deal_id", "count"),
          win_rate=("is_won", "mean"),
          revenue_generated=("deal_amount", "sum")
      )
      .reset_index()
)

win_rate_trend["win_rate"] *= 100
win_rate_trend['successful_deals'] = win_rate_trend['win_rate'] * win_rate_trend['deals']

win_rate_trend
# Out:
#   created_year_and_quarter  deals   win_rate  revenue_generated  \
# 0                   2023Q1   1006  43.737575           25286077
# 1                   2023Q2   1014  44.280079           27115555
# 2                   2023Q3   1006  46.620278           26375100
# 3                   2023Q4   1013  47.976308           26977557
# 4                   2024Q1    961  43.600416           25678175
#
#    successful_deals
# 0           44000.0
# 1           44900.0
# 2           46900.0
# 3           48600.0
# 4           41900.0

# %% [markdown]
# #### 2024 Q1 is down ~7% since the peak of last 2 Quarters
# #### At the same time, it is doing almost as par with last year's same quarter (2023 Q1). There may be a possibility of a seasonal dip.

# %%
plt.figure(figsize=(10, 4))
plt.plot(win_rate_trend["created_year_and_quarter"], win_rate_trend["win_rate"], marker="o")
plt.title("Win Rate Trend Over Time")
plt.ylabel("Win Rate (%)")
plt.xlabel("Quarter")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Segment Level Leakage

# %%
def win_rate_by_segment(df, col):
    return (
        df.groupby(["created_year_and_quarter",col])
          .agg(
              deals=("deal_id", "count"),
              win_rate=("is_won", "mean"),
              avg_acv=("deal_amount", "mean")
          )
          .assign(win_rate=lambda x: x["win_rate"] * 100)
          # .sort_values("win_rate")
    )

segments = ["region", "industry", "product_type", "lead_source"]

segment_tables = {
    seg: win_rate_by_segment(df, seg)
    for seg in segments
}

# %%
segment_tables['lead_source']
# Out:
#                                       deals   win_rate       avg_acv
# created_year_and_quarter lead_source
# 2023Q1                   Inbound        237  48.101266  24884.852321
#                          Outbound       240  43.333333  24680.979167
#                          Partner        263  39.543726  23593.733840
#                          Referral       266  44.360902  27292.406015
# 2023Q2                   Inbound        255  47.450980  27174.992157
#                          Outbound       246  47.560976  26847.264228
#                          Partner        251  38.645418  27919.872510
#                          Referral       262  43.511450  25090.141221
# 2023Q3                   Inbound        250  46.800000  29330.112000
#                          Outbound       251  45.019920  24939.095618
#                          Partner        265  49.056604  26261.362264
#                          Referral       240  45.416667  24264.991667
# 2023Q4                   Inbound        266  46.240602  26560.706767
#                          Outbound       255  49.019608  25698.760784
#                          Partner        251  49.402390  27438.601594
#                          Referral       241  47.302905  26855.336100
# 2024Q1                   Inbound        254  41.732283  27172.551181
#                          Outbound       254  42.519685  27596.775591
#                          Partner        210  42.857143  23889.009524
#                          Referral       243  47.325103  27778.082305
